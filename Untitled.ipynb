# %%
#Titanic Survival prediction

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt


train = pd.read_csv(r"C:\Users\Sai Sreeja\Downloads\Titanic-Dataset.csv")
train.shape
print(train)
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# 886                              Montvila, Rev. Juozas    male  27.0      0
# 887                       Graham, Miss. Margaret Edith  female  19.0      0
# 888           Johnston, Miss. Catherine Helen "Carrie"  female   NaN      1
# 889                              Behr, Mr. Karl Howell    male  26.0      0
# 890                                Dooley, Mr. Patrick    male  32.0      0
#
#      Parch            Ticket     Fare Cabin Embarked
# 0        0         A/5 21171   7.2500   NaN        S
# 1        0          PC 17599  71.2833   C85        C
# 2        0  STON/O2. 3101282   7.9250   NaN        S
# 3        0            113803  53.1000  C123        S
# 4        0            373450   8.0500   NaN        S
# ..     ...               ...      ...   ...      ...
# 886      0            211536  13.0000   NaN        S
# 887      0            112053  30.0000   B42        S
# 888      2        W./C. 6607  23.4500   NaN        S
# 889      0            111369  30.0000  C148        C
# 890      0            370376   7.7500   NaN        Q
#
# [891 rows x 12 columns]

# %%
numeric_columns = train.select_dtypes(include=[np.number]).columns

# %%
grouped_means = train.groupby('Survived')[numeric_columns].mean()
print(grouped_means)
# Out:
#           PassengerId  Survived    Pclass        Age     SibSp     Parch  \
# Survived
# 0          447.016393       0.0  2.531876  30.626179  0.553734  0.329690
# 1          444.368421       1.0  1.950292  28.343690  0.473684  0.464912
#
#                Fare
# Survived
# 0         22.117887
# 1         48.395408

# %%
total_male = len(train[train['Sex'] == 'male'])
total_female  = len(train[train['Sex'] == 'female'])
print("No of Males in Titanic:",total_male)
print("No of Females in Titanic:",total_female)
# Out:
# No of Males in Titanic: 577
# No of Females in Titanic: 314

# %%
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
gender = ['Male','Female']
index = [577,314]
ax.bar(gender,index)
plt.xlabel("Gender")
plt.ylabel("No of people onboarding ship")
plt.show()

# %%
alive = len(train[train['Survived'] == 1])
dead = len(train[train['Survived'] == 0])
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
status = ['Survived','Dead']
ind = [alive,dead]
ax.bar(status,ind)
plt.xlabel("Status")
plt.ylabel("No of people onboarding ship")
plt.show()

# %%
train.loc[train['Survived'] == 1, 'Pclass'].value_counts().sort_index().plot.bar()
plt.title('Bar graph of people according to ticket class in which people survived')
plt.xlabel('Ticket Class')
plt.ylabel('Number of Survivors')
plt.show()

# %%
train.loc[train['Survived'] == 0, 'Pclass'].value_counts().sort_index().plot.bar()
plt.title('Bar graph of people according to ticket class in which people couldnot survived')
plt.xlabel('Ticket Class')
plt.ylabel('Number of Survivors')
plt.show()

# %%
plt.figure(1)
age  = train.loc[train.Survived == 1, 'Age']
plt.title('The histogram of the age groups of the people that had survived')
plt.hist(age, np.arange(0,100,5))
plt.xticks(np.arange(0,100,5))
# Out:
# ([<matplotlib.axis.XTick at 0x1fd18ae5910>,
#   <matplotlib.axis.XTick at 0x1fd182ef510>,
#   <matplotlib.axis.XTick at 0x1fd1832c850>,
#   <matplotlib.axis.XTick at 0x1fd19012510>,
#   <matplotlib.axis.XTick at 0x1fd190280d0>,
#   <matplotlib.axis.XTick at 0x1fd1902a190>,
#   <matplotlib.axis.XTick at 0x1fd19034410>,
#   <matplotlib.axis.XTick at 0x1fd19036590>,
#   <matplotlib.axis.XTick at 0x1fd19038650>,
#   <matplotlib.axis.XTick at 0x1fd182cea10>,
#   <matplotlib.axis.XTick at 0x1fd1903a650>,
#   <matplotlib.axis.XTick at 0x1fd1903c950>,
#   <matplotlib.axis.XTick at 0x1fd1903e6d0>,
#   <matplotlib.axis.XTick at 0x1fd19040a90>,
#   <matplotlib.axis.XTick at 0x1fd1903db10>,
#   <matplotlib.axis.XTick at 0x1fd19043310>,
#   <matplotlib.axis.XTick at 0x1fd19049310>,
#   <matplotlib.axis.XTick at 0x1fd1904b490>,
#   <matplotlib.axis.XTick at 0x1fd19051490>,
#   <matplotlib.axis.XTick at 0x1fd1830b9d0>],
#  [Text(0, 0, '0'),
#   Text(5, 0, '5'),
#   Text(10, 0, '10'),
#   Text(15, 0, '15'),
#   Text(20, 0, '20'),
#   Text(25, 0, '25'),
#   Text(30, 0, '30'),
#   Text(35, 0, '35'),
#   Text(40, 0, '40'),
#   Text(45, 0, '45'),
#   Text(50, 0, '50'),
#   Text(55, 0, '55'),
#   Text(60, 0, '60'),
#   Text(65, 0, '65'),
#   Text(70, 0, '70'),
#   Text(75, 0, '75'),
#   Text(80, 0, '80'),
#   Text(85, 0, '85'),
#   Text(90, 0, '90'),
#   Text(95, 0, '95')])

# %%
plt.figure(1)
age  = train.loc[train.Survived == 1, 'Age']
plt.title('The histogram of the age groups of the people that had survived')
plt.hist(age, np.arange(0,100,10))
plt.xticks(np.arange(0,100,10))
# Out:
# ([<matplotlib.axis.XTick at 0x1fd182cd690>,
#   <matplotlib.axis.XTick at 0x1fd19084090>,
#   <matplotlib.axis.XTick at 0x1fd1819ba90>,
#   <matplotlib.axis.XTick at 0x1fd190cd250>,
#   <matplotlib.axis.XTick at 0x1fd190d0350>,
#   <matplotlib.axis.XTick at 0x1fd190d2490>,
#   <matplotlib.axis.XTick at 0x1fd190d3550>,
#   <matplotlib.axis.XTick at 0x1fd190e1650>,
#   <matplotlib.axis.XTick at 0x1fd190e33d0>,
#   <matplotlib.axis.XTick at 0x1fd190e57d0>],
#  [Text(0, 0, '0'),
#   Text(10, 0, '10'),
#   Text(20, 0, '20'),
#   Text(30, 0, '30'),
#   Text(40, 0, '40'),
#   Text(50, 0, '50'),
#   Text(60, 0, '60'),
#   Text(70, 0, '70'),
#   Text(80, 0, '80'),
#   Text(90, 0, '90')])

# %%
plt.figure(1)
age  = train.loc[train.Survived == 0, 'Age']
plt.title('The histogram of the age groups of the people that couldnot survived')
plt.hist(age, np.arange(0,100,10))
plt.xticks(np.arange(0,100,10))
# Out:
# ([<matplotlib.axis.XTick at 0x1fd190eb950>,
#   <matplotlib.axis.XTick at 0x1fd19122010>,
#   <matplotlib.axis.XTick at 0x1fd19041c90>,
#   <matplotlib.axis.XTick at 0x1fd1915dfd0>,
#   <matplotlib.axis.XTick at 0x1fd1915ffd0>,
#   <matplotlib.axis.XTick at 0x1fd1916a110>,
#   <matplotlib.axis.XTick at 0x1fd1916c310>,
#   <matplotlib.axis.XTick at 0x1fd1916e410>,
#   <matplotlib.axis.XTick at 0x1fd191745d0>,
#   <matplotlib.axis.XTick at 0x1fd1916dd10>],
#  [Text(0, 0, '0'),
#   Text(10, 0, '10'),
#   Text(20, 0, '20'),
#   Text(30, 0, '30'),
#   Text(40, 0, '40'),
#   Text(50, 0, '50'),
#   Text(60, 0, '60'),
#   Text(70, 0, '70'),
#   Text(80, 0, '80'),
#   Text(90, 0, '90')])

# %%
train[["Pclass", "Survived"]].groupby(['Pclass'], as_index=False).mean().sort_values(by='Survived', ascending=False)
# Out:
#    Pclass  Survived
# 0       1  0.629630
# 1       2  0.472826
# 2       3  0.242363

# %%
train[["Age", "Survived"]].groupby(['Age'], as_index=False).mean().sort_values(by='Age', ascending=True)
# Out:
#       Age  Survived
# 0    0.42       1.0
# 1    0.67       1.0
# 2    0.75       1.0
# 3    0.83       1.0
# 4    0.92       1.0
# ..    ...       ...
# 83  70.00       0.0
# 84  70.50       0.0
# 85  71.00       0.0
# 86  74.00       0.0
# 87  80.00       1.0
#
# [88 rows x 2 columns]

# %%
train = train.drop(['Ticket', 'Cabin', 'Name'], axis=1)

# %%
train['Age'].fillna(train['Age'].median(), inplace=True)
train['Embarked'].fillna(train['Embarked'].mode()[0], inplace=True)
train = pd.get_dummies(train, columns=['Sex', 'Embarked'], drop_first=True)

# %%
column_train = ['Age', 'Pclass', 'SibSp', 'Parch', 'Fare', 'Sex_male', 'Embarked_Q', 'Embarked_S']
X = train[column_train]
Y = train['Survived']
print(X.head())
print(Y.head())
# Out:
#     Age  Pclass  SibSp  Parch     Fare  Sex_male  Embarked_Q  Embarked_S
# 0  22.0       3      1      0   7.2500      True       False        True
# 1  38.0       1      1      0  71.2833     False       False       False
# 2  26.0       3      0      0   7.9250     False       False        True
# 3  35.0       1      1      0  53.1000     False       False        True
# 4  35.0       3      0      0   8.0500      True       False        True
# 0    0
# 1    1
# 2    1
# 3    1
# 4    0
# Name: Survived, dtype: int64

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, Y_train, Y_test = train_test_split(X,Y,test_size=0.3,random_state=7)

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2, random_state=42)

scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

model = LogisticRegression(max_iter=200, solver='liblinear')
model.fit(X_train, Y_train)
Y_pred = model.predict(X_test)

print("Accuracy Score:", accuracy_score(Y_test, Y_pred))
# Out:
# Accuracy Score: 0.8100558659217877

# %%
from sklearn.svm import SVC
model1 = SVC()
model1.fit(X_train,Y_train)

pred_y = model1.predict(X_test)

from sklearn.metrics import accuracy_score
print("Acc=",accuracy_score(Y_test,pred_y))
# Out:
# Acc= 0.8212290502793296

# %%
from sklearn.neighbors import KNeighborsClassifier
model2 = KNeighborsClassifier(n_neighbors=5)
model2.fit(X_train,Y_train)
y_pred2 = model2.predict(X_test)

from sklearn.metrics import accuracy_score
print("Accuracy Score:",accuracy_score(Y_test,y_pred2))
# Out:
# Accuracy Score: 0.8044692737430168

# %%
from sklearn.naive_bayes import GaussianNB
model3 = GaussianNB()
model3.fit(X_train,Y_train)
y_pred3 = model3.predict(X_test)

from sklearn.metrics import accuracy_score
print("Accuracy Score:",accuracy_score(Y_test,y_pred3))
# Out:
# Accuracy Score: 0.770949720670391

# %%
from sklearn.tree import DecisionTreeClassifier
model4 = DecisionTreeClassifier(criterion='entropy',random_state=7)
model4.fit(X_train,Y_train)
y_pred4 = model4.predict(X_test)

from sklearn.metrics import accuracy_score
print("Accuracy Score:",accuracy_score(Y_test,y_pred4))
# Out:
# Accuracy Score: 0.7877094972067039

# %%
results = pd.DataFrame({
    'Model': ['Logistic Regression','Support Vector Machines','KNN' , 'Naive Bayes','Decision Tree'],
    'Score': [0.81,0.82,0.80,0.77,0.78]})

result_df = results.sort_values(by='Score', ascending=False)
result_df = result_df.set_index('Score')
result_df.head(9)
# Out:
#                          Model
# Score
# 0.82   Support Vector Machines
# 0.81       Logistic Regression
# 0.80                       KNN
# 0.78             Decision Tree
# 0.77               Naive Bayes

# %%
#Hence I will use SVM for training my model
